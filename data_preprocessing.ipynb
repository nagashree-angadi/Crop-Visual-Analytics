# %%
import pandas as pd
import numpy as np

# %%
! ls ./static/Data/
# Out:
# PreprocessedData.csv                   Production_Crops_E_Flags.csv
# Production_Crops_E_All_Data.csv        countries&regions.csv
# Production_Crops_E_All_Data_NOFLAG.csv

# %%
crops = pd.read_csv("./static/Data/Production_Crops_E_All_Data.csv", encoding = "ISO-8859-1")
crops_noflag = pd.read_csv("./static/Data/Production_Crops_E_All_Data_NOFLAG.csv", encoding = "ISO-8859-1")
crops_eflag = pd.read_csv("./static/Data/Production_Crops_E_Flags.csv", encoding = "ISO-8859-1")
regions = pd.read_csv("./static/Data/countries&regions.csv", encoding = "ISO-8859-1")

# %%
crops.head()
# Out:
#    Area Code         Area  Item Code                              Item  \
# 0          2  Afghanistan        221               Almonds, with shell
# 1          2  Afghanistan        221               Almonds, with shell
# 2          2  Afghanistan        221               Almonds, with shell
# 3          2  Afghanistan        711  Anise, badian, fennel, coriander
# 4          2  Afghanistan        711  Anise, badian, fennel, coriander
#
#    Element Code         Element    Unit  Y1961 Y1961F  Y1962  ...    Y2014  \
# 0          5312  Area harvested      ha    NaN    NaN    NaN  ...  13703.0
# 1          5419           Yield   hg/ha    NaN    NaN    NaN  ...  19996.0
# 2          5510      Production  tonnes    NaN    NaN    NaN  ...  27400.0
# 3          5312  Area harvested      ha    NaN      M    NaN  ...  30000.0
# 4          5419           Yield   hg/ha    NaN    NaN    NaN  ...   7167.0
#
#    Y2014F    Y2015  Y2015F    Y2016  Y2016F    Y2017  Y2017F    Y2018  Y2018F
# 0     NaN  14676.0     NaN  19481.0     NaN  19793.0     NaN  20053.0     NaN
# 1      Fc  16521.0      Fc  16859.0      Fc  13788.0      Fc  17161.0      Fc
# 2     NaN  24246.0     NaN  32843.0     NaN  27291.0     NaN  34413.0     NaN
# 3       F  25000.0       F  25638.0      Im  27582.0      Im  25785.0      Im
# 4      Fc   7200.0      Fc   7037.0      Fc   6954.0      Fc   7036.0      Fc
#
# [5 rows x 123 columns]

# %%
crops_noflag.head()
# Out:
#    Area Code         Area  Item Code                              Item  \
# 0          2  Afghanistan        221               Almonds, with shell
# 1          2  Afghanistan        221               Almonds, with shell
# 2          2  Afghanistan        221               Almonds, with shell
# 3          2  Afghanistan        711  Anise, badian, fennel, coriander
# 4          2  Afghanistan        711  Anise, badian, fennel, coriander
#
#    Element Code         Element    Unit  Y1961  Y1962  Y1963  ...    Y2009  \
# 0          5312  Area harvested      ha    NaN    NaN    NaN  ...  11029.0
# 1          5419           Yield   hg/ha    NaN    NaN    NaN  ...  39154.0
# 2          5510      Production  tonnes    NaN    NaN    NaN  ...  43183.0
# 3          5312  Area harvested      ha    NaN    NaN    NaN  ...  17748.0
# 4          5419           Yield   hg/ha    NaN    NaN    NaN  ...   6203.0
#
#      Y2010    Y2011    Y2012    Y2013    Y2014    Y2015    Y2016    Y2017  \
# 0  11210.0  13469.0  13490.0  14114.0  13703.0  14676.0  19481.0  19793.0
# 1  49955.0  45000.0  45960.0  29910.0  19996.0  16521.0  16859.0  13788.0
# 2  56000.0  60611.0  62000.0  42215.0  27400.0  24246.0  32843.0  27291.0
# 3  17000.0  19500.0  18500.0  18500.0  30000.0  25000.0  25638.0  27582.0
# 4   6000.0   6414.0   6757.0   6757.0   7167.0   7200.0   7037.0   6954.0
#
#      Y2018
# 0  20053.0
# 1  17161.0
# 2  34413.0
# 3  25785.0
# 4   7036.0
#
# [5 rows x 65 columns]

# %%
crops_eflag.head()
# Out:
#       Flag                                        Description
# 0        *                                  Unofficial figure
# 1        /           Symbol for indigenous or liveweight meat
# 2  <blank>                                      Official data
# 3        A  Aggregate; may include official; semi-official...
# 4        C                                         Calculated

# %%
regions.head()
# Out:
#    Country Group Code Country Group  Country Code  \
# 0                5100        Africa             4
# 1                5100        Africa             7
# 2                5100        Africa            53
# 3                5100        Africa            20
# 4                5100        Africa            24
#
#                           Country  M49 Code ISO2 Code ISO3 Code
# 0                         Algeria      12.0        DZ       DZA
# 1                          Angola      24.0        AO       AGO
# 2                           Benin     204.0        BJ       BEN
# 3                        Botswana      72.0        BW       BWA
# 4  British Indian Ocean Territory      86.0        IO       IOT

# %%
# Checking the shape of file
crops_noflag.shape
# Out:
# (51154, 65)

# %%
# Dropping unnessasary columns
crops_noflag.drop(columns=["Element Code", "Unit"], inplace=True)
crops_noflag.rename(columns={"Item": "Crop", 
                             "Item Code": "Crop Code", 
                             "Area" : "Country",
                             "Area Code" : "Country Code",
                             "Element" : "Type"}, inplace = True)
crops_noflag.head()
# Out:
#    Country Code      Country  Crop Code                              Crop  \
# 0             2  Afghanistan        221               Almonds, with shell
# 1             2  Afghanistan        221               Almonds, with shell
# 2             2  Afghanistan        221               Almonds, with shell
# 3             2  Afghanistan        711  Anise, badian, fennel, coriander
# 4             2  Afghanistan        711  Anise, badian, fennel, coriander
#
#              Type  Y1961  Y1962  Y1963  Y1964  Y1965  ...    Y2009    Y2010  \
# 0  Area harvested    NaN    NaN    NaN    NaN    NaN  ...  11029.0  11210.0
# 1           Yield    NaN    NaN    NaN    NaN    NaN  ...  39154.0  49955.0
# 2      Production    NaN    NaN    NaN    NaN    NaN  ...  43183.0  56000.0
# 3  Area harvested    NaN    NaN    NaN    NaN    NaN  ...  17748.0  17000.0
# 4           Yield    NaN    NaN    NaN    NaN    NaN  ...   6203.0   6000.0
#
#      Y2011    Y2012    Y2013    Y2014    Y2015    Y2016    Y2017    Y2018
# 0  13469.0  13490.0  14114.0  13703.0  14676.0  19481.0  19793.0  20053.0
# 1  45000.0  45960.0  29910.0  19996.0  16521.0  16859.0  13788.0  17161.0
# 2  60611.0  62000.0  42215.0  27400.0  24246.0  32843.0  27291.0  34413.0
# 3  19500.0  18500.0  18500.0  30000.0  25000.0  25638.0  27582.0  25785.0
# 4   6414.0   6757.0   6757.0   7167.0   7200.0   7037.0   6954.0   7036.0
#
# [5 rows x 63 columns]

# %%
# Dropping aggregated values from countries column
agg = regions["Country Group"].unique()
crops_noflag = crops_noflag[~crops_noflag["Country"].isin(agg)]

# %%
# Checking the null values in data set
crops_noflag.isnull().sum().reset_index()
# Out:
#            index     0
# 0   Country Code     0
# 1        Country     0
# 2      Crop Code     0
# 3           Crop     0
# 4           Type     0
# ..           ...   ...
# 58         Y2014  3371
# 59         Y2015  4899
# 60         Y2016  4885
# 61         Y2017  4872
# 62         Y2018  4857
#
# [63 rows x 2 columns]

# %%
# Imputing the null values
crops_noflag.fillna(0, inplace=True)

# %%
# Tranforming data in usable format
years = ['Y1961','Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967', 'Y1968', 'Y1969',
       'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975', 'Y1976', 'Y1977',
       'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983', 'Y1984', 'Y1985',
       'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y1991', 'Y1992', 'Y1993',
       'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998', 'Y1999', 'Y2000', 'Y2001',
       'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007', 'Y2008', 'Y2009',
       'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015', 'Y2016', 'Y2017','Y2018']

data = pd.melt(crops_noflag, id_vars=['Country Code', 'Country', 'Crop Code', 'Crop', 'Type'], value_vars=years)
data = data.rename( columns = {"variable":"Year", "value":"Value" })
data["Year"] = data["Year"].apply( lambda x: int(x[1:]))
data["Value"] = data["Value"].astype(int)

# %%
# Writing the data to local dir
data.to_csv("./static/Data/PreprocessedData.csv", index=False)

# %%
data.columns
# Out:
# Index(['Country Code', 'Country', 'Crop Code', 'Crop', 'Type', 'Year',
#        'Value'],
#       dtype='object')

# %%
data.head()
# Out:
#    Country Code      Country  Crop Code                              Crop  \
# 0             2  Afghanistan        221               Almonds, with shell
# 1             2  Afghanistan        221               Almonds, with shell
# 2             2  Afghanistan        221               Almonds, with shell
# 3             2  Afghanistan        711  Anise, badian, fennel, coriander
# 4             2  Afghanistan        711  Anise, badian, fennel, coriander
#
#              Type  Year  Value
# 0  Area harvested  1961      0
# 1           Yield  1961      0
# 2      Production  1961      0
# 3  Area harvested  1961      0
# 4           Yield  1961      0

# %%
# Total yeild per country
df = data[data.Type == "Yield"][["Country", "Value"]]
df = df.groupby(["Country"]).sum().reset_index()

res = []
for country,value in df.values:
    res.append(
    {
        "country" : country,
        "value" : value
    })
    
print(res)
# Out:
# [{'country': 'Afghanistan', 'value': 136147698}, {'country': 'Albania', 'value': 241808491}, {'country': 'Algeria', 'value': 301612244}, {'country': 'American Samoa', 'value': 34370689}, {'country': 'Angola', 'value': 95114166}, {'country': 'Antigua and Barbuda', 'value': 189336596}, {'country': 'Argentina', 'value': 342759988}, {'country': 'Armenia', 'value': 113654146}, {'country': 'Australia', 'value': 617725095}, {'country': 'Austria', 'value': 485011698}, {'country': 'Azerbaijan', 'value': 124663703}, {'country': 'Bahamas', 'value': 126564366}, {'country': 'Bahrain', 'value': 241895887}, {'country': 'Bangladesh', 'value': 195782544}, {'country': 'Barbados', 'value': 169723158}, {'country': 'Belarus', 'value': 88077818}, {'country': 'Belgium', 'value': 438231171}, {'country': 'Belgium-Luxembourg', 'value': 507825551}, {'country': 'Belize', 'value': 187846967}, {'country': 'Benin', 'value': 110839102}, {'country': 'Bermuda', 'value': 102769939}, {'country': 'Bhutan', 'value': 74423774}, {'country': 'Bolivia (Plurinational State of)', 'value': 206982082}, {'country': 'Bosnia and Herzegovina', 'value': 75264352}, {'country': 'Botswana', 'value': 50147378}, {'country': 'Brazil', 'value': 349103906}, {'country': 'British Virgin Islands', 'value': 13249774}, {'country': 'Brunei Darussalam', 'value': 69061344}, {'country': 'Bulgaria', 'value': 348823028}, {'country': 'Burkina Faso', 'value': 194884413}, {'country': 'Burundi', 'value': 91896068}, {'country': 'Cabo Verde', 'value': 154920053}, {'country': 'Cambodia', 'value': 104457092}, {'country': 'Cameroon', 'value': 137628805}, {'country': 'Canada', 'value': 335565101}, {'country': 'Cayman Islands', 'value': 61219